# %%
                              #Point Operation
 
from skimage import io
import matplotlib.pyplot as plt
 
def f(x):
  return (x-10)
 
def point_operation(image,method):
  for row in range(0,image.shape[0]):
    for col in range(0,image.shape[1]):
      image[row][col]=method(image[row][col])
  return image
 
if __name__=='__main__':
  image=io.imread('image1.jpg')
  image_modified = point_operation(image.copy(),f)
  plt.figure()
  _=io.imshow(image)
  plt.figure()
  _=io.imshow(image_modified)
  plt.show()

# %%
#image cropping

from PIL import Image
im = Image.open('image2.jpg')
plt.imshow(im)
plt.show()
im = im.crop((30,350,620,630))
plt.imshow(im)
plt.show()
im.save('CroppedShip.jpg')
